# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
df=pd.read_csv('../Data/data.csv')

# %% [markdown]
# feature engineering the result should here that contain in the columnets  that are added becaus of feature enfinering like

# %%
sys.path.append(os.path.abspath('../script'))

# %%
from feature_engineering import feature_engineering

# %% [markdown]
# calling feature engineering funciton form feature engineering.py file and i show the result of newly created values
# IT WORKS THE FOLLOWING
#
# --- Creating Aggregate Features ---
#
# --- Extracting Date-Based Features ---
#
# --- Encoding Categorical Variables ---
#
# --- Handling Missing Values ---
#
# --- Normalizing/Standardizing Numerical Features ---
#
# --- Feature Engineering with WOE ---

# %%
fedf=feature_engineering(df)
fedf.head(10)
# Out:
# --- Creating Aggregate Features ---
#
# --- Extracting Date-Based Features ---
#
# --- Encoding Categorical Variables ---
#
# --- Handling Missing Values ---
#
# --- Normalizing/Standardizing Numerical Features ---
#
# --- Feature Engineering with WOE ---
# Feature Engineering completed successfully!
#           TransactionId         BatchId       AccountId       SubscriptionId  \
# 0   TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1   TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2   TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3     TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4   TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
# 5   TransactionId_23223   BatchId_25954  AccountId_1078  SubscriptionId_4238
# 6  TransactionId_118063  BatchId_118460  AccountId_2442  SubscriptionId_1980
# ...
