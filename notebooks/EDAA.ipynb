# %% [markdown]
# importing pandas adn sys to add the path

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# loading the data from data folder

# %%
df=pd.read_csv('../Data/data.csv')

# %% [markdown]
# APPENDING SCRIPT DIECTORY TO THE CODE TO IMPORT THE of EDA AND FEATURE EXTRACTION

# %%
sys.path.append(os.path.abspath('../script'))

# %% [markdown]
# IMPORTING THE PERFORM EDA FUNCITON FORM EDA.PY

# %%
from EDA import perform_eda

# %%
perform_eda(df)
# Out:
# --- Dataset Overview ---
# Number of rows: 95662
# Number of columns: 16
#
# --- Data Types ---
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# --- Summary Statistics ---
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# unique                95662          94809            3633
# top     TransactionId_35670  BatchId_67019  AccountId_4841
# freq                      1             28           30893
# mean                    NaN            NaN             NaN
# std                     NaN            NaN             NaN
# min                     NaN            NaN             NaN
# 25%                     NaN            NaN             NaN
# 50%                     NaN            NaN             NaN
# 75%                     NaN            NaN             NaN
# max                     NaN            NaN             NaN
#
#              SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# count                 95662            95662        95662      95662.0
# unique                 3627             3742            1          NaN
# top     SubscriptionId_3829  CustomerId_7343          UGX          NaN
# freq                  32630             4091        95662          NaN
# mean                    NaN              NaN          NaN        256.0
# std                     NaN              NaN          NaN          0.0
# min                     NaN              NaN          NaN        256.0
# 25%                     NaN              NaN          NaN        256.0
# 50%                     NaN              NaN          NaN        256.0
# 75%                     NaN              NaN          NaN        256.0
# max                     NaN              NaN          NaN        256.0
#
#           ProviderId    ProductId     ProductCategory    ChannelId  \
# count          95662        95662               95662        95662
# unique             6           23                   9            4
# top     ProviderId_4  ProductId_6  financial_services  ChannelId_3
# freq           38189        32635               45405        56935
# mean             NaN          NaN                 NaN          NaN
# std              NaN          NaN                 NaN          NaN
# min              NaN          NaN                 NaN          NaN
# 25%              NaN          NaN                 NaN          NaN
# 50%              NaN          NaN                 NaN          NaN
# 75%              NaN          NaN                 NaN          NaN
# max              NaN          NaN                 NaN          NaN
#
#               Amount         Value  TransactionStartTime  PricingStrategy  \
# count   9.566200e+04  9.566200e+04                 95662     95662.000000
# unique           NaN           NaN                 94556              NaN
# top              NaN           NaN  2018-12-24T16:30:13Z              NaN
# freq             NaN           NaN                    17              NaN
# mean    6.717846e+03  9.900584e+03                   NaN         2.255974
# std     1.233068e+05  1.231221e+05                   NaN         0.732924
# min    -1.000000e+06  2.000000e+00                   NaN         0.000000
# 25%    -5.000000e+01  2.750000e+02                   NaN         2.000000
# 50%     1.000000e+03  1.000000e+03                   NaN         2.000000
# 75%     2.800000e+03  5.000000e+03                   NaN         2.000000
# max     9.880000e+06  9.880000e+06                   NaN         4.000000
#
#          FraudResult
# count   95662.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.002018
# std         0.044872
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# --- Missing Values ---
# Series([], dtype: int64)
#
# --- Distribution of Numerical Features ---
# --- Distribution of Categorical Features ---

# %%
# Out:
# --- Creating Aggregate Features ---
#
# --- Extracting Date-Based Features ---
#
# --- Encoding Categorical Variables ---
#
# --- Handling Missing Values ---
#
# --- Normalizing/Standardizing Numerical Features ---
#
# --- Feature Engineering with WOE ---
# Feature Engineering completed successfully!
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          0.0
# 1      SubscriptionId_3829  CustomerId_4406          UGX          0.0
# 2       SubscriptionId_222  CustomerId_4683          UGX          0.0
# 3      SubscriptionId_2185   CustomerId_988          UGX          0.0
# 4      SubscriptionId_3829   CustomerId_988          UGX          0.0
# ...                    ...              ...          ...          ...
# 95657  SubscriptionId_3829  CustomerId_3078          UGX          0.0
# 95658  SubscriptionId_2643  CustomerId_3874          UGX          0.0
# 95659  SubscriptionId_3829  CustomerId_3874          UGX          0.0
# 95660   SubscriptionId_652  CustomerId_1709          UGX          0.0
# 95661  SubscriptionId_3829  CustomerId_1709          UGX          0.0
#
#          ProviderId     ProductId     ProductCategory  ... woe_WOE_BatchId  \
# 0      ProviderId_6  ProductId_10             airtime  ...        -4.66104
# 1      ProviderId_4   ProductId_6  financial_services  ...        -4.66104
# 2      ProviderId_6   ProductId_1             airtime  ...        -4.66104
# 3      ProviderId_1  ProductId_21        utility_bill  ...        -4.66104
# 4      ProviderId_4   ProductId_6  financial_services  ...        -4.66104
# ...             ...           ...                 ...  ...             ...
# 95657  ProviderId_4   ProductId_6  financial_services  ...        -4.66104
# 95658  ProviderId_6  ProductId_10             airtime  ...        -4.66104
# 95659  ProviderId_4   ProductId_6  financial_services  ...        -4.66104
# 95660  ProviderId_6  ProductId_19                  tv  ...        -4.66104
# 95661  ProviderId_4   ProductId_6  financial_services  ...        -4.66104
#
#        woe_WOE_AccountId  woe_WOE_SubscriptionId woe_WOE_CustomerId  \
# 0              -8.841338               -8.841338          -9.430743
# 1              -4.134367               -4.189071          -9.430743
# 2              -5.349448               -5.349448          -5.349448
# 3              -7.910002               -7.910002          -8.289376
# 4              -4.134367               -4.189071          -8.289376
# ...                  ...                     ...                ...
# 95657          -4.134367               -4.189071         -11.002441
# 95658          -7.947729               -7.947729          -8.412961
# 95659          -4.134367               -4.189071          -8.412961
# 95660         -10.509499              -10.509499         -10.913049
# 95661          -4.134367               -4.189071         -10.913049
#
#        woe_WOE_CurrencyCode  woe_WOE_ProviderId  woe_WOE_ProductId  \
# 0                       0.0           -3.136999          -1.645064
# 1                       0.0           -2.736864          -4.189224
# 2                       0.0           -3.136999         -12.618822
# 3                       0.0            1.618898           0.271620
# 4                       0.0           -2.736864          -4.189224
# ...                     ...                 ...                ...
# 95657                   0.0           -2.736864          -4.189224
# 95658                   0.0           -3.136999          -1.645064
# 95659                   0.0           -2.736864          -4.189224
# 95660                   0.0           -3.136999         -11.523677
# 95661                   0.0           -2.736864          -4.189224
#
#        woe_WOE_ProductCategory  woe_WOE_ChannelId  \
# 0                    -1.620378           0.472374
# 1                     0.565446          -2.709034
# 2                    -1.620378           0.472374
# 3                     1.134959           0.472374
# 4                     0.565446          -2.709034
# ...                        ...                ...
# 95657                 0.565446          -2.709034
# 95658                -1.620378           0.472374
# 95659                 0.565446          -2.709034
# 95660               -11.805380           0.472374
# 95661                 0.565446          -2.709034
#
#        woe_WOE_TransactionStartTime
# 0                          -4.66104
# 1                          -4.66104
# 2                          -4.66104
# 3                          -4.66104
# 4                          -4.66104
# ...                             ...
# 95657                      -4.66104
# 95658                      -4.66104
# 95659                      -4.66104
# 95660                      -4.66104
# 95661                      -4.66104
#
# [95662 rows x 79 columns]

# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))
from EDA import perform_eda

# perform_eda(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath('../src'))
# ----> 4 from EDA import perform_eda
#       6 perform_eda(df)
#
# ImportError: cannot import name 'perform_eda' from 'EDA' (c:\Users\User\Desktop\Bank-Credit-Scoring-Model\src\EDA.py)
